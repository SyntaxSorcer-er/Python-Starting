# %%
inp = input()

numbers = inp.split()

x = int(numbers[0])
y = int(numbers[1])
z = int(numbers[2])

min = x
max = x

## for min
if y < min :
    min = y
if z < min :
    min = z

## for max
if y > max :
    max = y
if z > max :
    max = z

print(min, max)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 6
#       2
#       3 numbers = inp.split()
#       4
#       5 x = int(numbers[0])
# ----> 6 y = int(numbers[1])
#       7 z = int(numbers[2])
#       8
#       9 min = x
#
# IndexError: list index out of range
