# %%
phone_number= 1309883852

print(phone_number)
# Out:
# 1309883852

# %%
name= 'Yasir Fuad'

print(name)
# Out:
# Yasir Fuad

# %%
name='Yasir Fuad'
age= 23
height= 5.10
address= 'Alamdanga, Chuadanga'
university= 'AIUB'
status= True
print(type(name),type(age),type(height),type(address),type(university),type(status))
Age= 30
print(age,Age)
print(name,age,height,address,university,status)
print(name,"\n",age,"\n",height,"\n",address,"\n",university,"\n",status)
# Out:
# <class 'str'> <class 'int'> <class 'float'> <class 'str'> <class 'str'> <class 'bool'>
# 23 30
# Yasir Fuad 23 5.1 Alamdanga, Chuadanga AIUB True
# Yasir Fuad
#  23
#  5.1
#  Alamdanga, Chuadanga
#  AIUB
#  True
