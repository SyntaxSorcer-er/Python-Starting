# %%
name = input("What is your name? ")
print(name)
# Out:
# Fuad

# %%
age = input("Age ?")
print(age , type(age))
# Out:
# 23 <class 'str'>

# %%
age = input("Age ?") #Input as String
age = int(age) #Converted to Integer
print(age , type(age))
# Out:
# 20 <class 'int'>

# %%
height = input("Height ?")
print(height , type(height))
# Out:
# 5.10 <class 'str'>

# %%
height = float(input("Height ?"))
print(height , type(height))
height = height + 0.2
print(height)
# Out:
# 5.0 <class 'float'>
# 5.2
