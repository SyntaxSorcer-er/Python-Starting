# %% [markdown]
# Problem : Digit Summation

# %%
# though answer is correct but method is wrong 
x = int(input())
y = int(input())

last_digit_of_x = x % 10
last_digit_of_y = y % 10

sum = last_digit_of_x + last_digit_of_y
print(sum)
# Out:
# 7

# %%
x = input()

print(x , type( x))
# Out:
# 13 12 <class 'str'>

# %%
inp = input()
numbers = inp.split()
print(numbers)
# Out:
# ['12', '13']

# %%
inp = input()
numbers = inp.split()

x = numbers[0]
y = numbers[1]

print(type(x) , type(y))
# Out:
# <class 'str'> <class 'str'>

# %%
#Correct Method
inp = input()
numbers = inp.split()

x = int(numbers[0])
y = int(numbers[1])

last_digit_of_x = x % 10
last_digit_of_y = y % 10

sum = last_digit_of_x + last_digit_of_y

print(sum)
# Out:
# 5
