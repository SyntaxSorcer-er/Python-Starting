# %%
square = {x:x**2 for x in range(10) if x % 2 == 0}

print(square)
# Out:
# {0: 0, 2: 4, 4: 16, 6: 36, 8: 64}

# %%
co_ordinates = [(10, 10.5), (20.5, 192), (101, 102)]
locations = ["Dahaka", "Khulna", "Sylhet"]

exact_location = { co_or : loc for co_or, loc in zip(co_ordinates, locations) }

print(exact_location)
# Out:
# {(10, 10.5): 'Dahaka', (20.5, 192): 'Khulna', (101, 102): 'Sylhet'}
