# %% [markdown]
# Conditional Statements in Python

# %%
raining = True 
#raining = False
muddy = True

if raining == True:
    print("Rain coat is necessary")
    print("Caution")
    if muddy == True:
        print("Sandal is necessary")
else: 
    print("Go without a rain coat")
    print("This is a sunny day")
# Out:
# Go without a rain coat
# This is a sunny day

# %%
taka = 1000
raining = False

if (taka > 500 and raining == False) : 
    print("Ghurte Jabo")
elif (taka > 400 and raining == True) :
    print("Basai order korbo")
elif (taka > 300 and raining == False) :
    print("Food court a jabo")
else : 
    print("Taka ta save korbo")
# Out:
# Ghurte Jabo
