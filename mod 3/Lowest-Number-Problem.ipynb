# %%
n = int(input())
inp = input()
numbers = inp.split()

for i in range(n) :
    x = int(numbers[i])

    
    if x == :
        print(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 9
#       5 for i in range(n) :
#       6     x = int(numbers[i])
#       7
#       8
# ----> 9     if x == numbers.min() :
#      10         print(x)
#      11
#      12
#
# AttributeError: 'list' object has no attribute 'min'
