# %%
prompt = "What is your name?"

print(prompt)
print(type(prompt))
# Out:
# What is your name?
# <class 'str'>

# %%
message = """tell me about yourself
what is your name?
how are you?
who are you?
"""
print(message)
# Out:
# tell me about yourself
# what is your name?
# how are you?
# who are you?

# %% [markdown]
# Indexing

# %%
string = "Hello World"
print(string[0])
print(string[1])
print(string[2])
print(string[3])
print(string[4])
print(string[5])
print(string[6])
print(string[7])
print(string[8])
print(string[9])
print(string[10])
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d

# %% [markdown]
# Slicing

# %%
first_message = message[0:23]  #[strat:end]
second_message = prompt[13:18]  #[stert:end]
third_message = message[0:23:2]  # [start:end:step]
print(first_message)
print(second_message)
print(third_message)
# Out:
# tell me about yourself
#
# name?
# tl eaotyusl
